# %%
import json
import requests
import pprint
import os, sys, shutil
import pandas as pd

# %%
# API Interface

#  Host
#API_host = "http://dirac.nist.gov/adsorption.nist.gov"
API_host = "https://adsorption.nist.gov"

#  API Function
API_call = "/matdb/api/materials.json"

#  Suppress Google Analytics Tracking
#tracking_key = ""
tracking_key = "&k=dontrackmeplease"

#  Assemble the HTTP request
URL = API_host + API_call + tracking_key

#  Call API and load results into a dictionary
materials = json.loads(requests.get(URL).content)

#  Basic Output
#print(len(materials))
#pprint.pprint(materials[0])
#for material in materials[0:6]:
#    pprint.pprint(material)

# %%
#  Construct a synonym table
hashes = []
synonyms = []
#i = 0
for material in materials:
    hashes.append(material["hashkey"])
    synonyms.append(material["name"])
    for synonym in material["synonyms"]:
        hashes.append(material["hashkey"])
        synonyms.append(synonym)
    #i+=1
    #if i == 5: break
    #if len(material["synonyms"]) > 2: break

#for (hash,synonym) in zip(hashes,synonyms):
#    print(hash, synonym)
#print(len(hashes))
#print(len(synonyms))

#  Enter the results into a Pandas DataFrame for easier manipulation
materials_df = pd.DataFrame({ "hashkey": hashes, "synonym": synonyms })

# %%
materials_df
# Out:
#                                           hashkey  \
# 0     NIST-MATDB-70f6c5cfd34cb7fca06b59d6350f5303
# 1     NIST-MATDB-895aa514507d242d5062b7a2742cea92
# 2     NIST-MATDB-5e3af1000c584273e5f95543ff0a5113
# 3     NIST-MATDB-5d3d5a9b155b412206b0bbfd0bc76fb3
# 4     NIST-MATDB-545cd11abec564fcc3b346fdf97894c7
# 5     NIST-MATDB-de465fe168bf0755c57cca924412bbe6
# 6     NIST-MATDB-96551cec3480eda20771d3d9b7c6231b
# 7     NIST-MATDB-f7736d41443a15671f5e8d0df925a42c
# 8     NIST-MATDB-36ecd9f5a13fc408dc22098d7cd838a3
# 9     NIST-MATDB-05f26bb684c88e29819021cf451b60e2
# 10    NIST-MATDB-705be57511587b5cf26d1a79e4a8dbfd
# 11    NIST-MATDB-388cc8bc1b7ae9f6af22eb91a0a0c533
# 12    NIST-MATDB-b142150d6b54a92cea0bc0d437973f06
# 13    NIST-MATDB-edcc9fccf27cc5489a4652d9fe136ee2
# 14    NIST-MATDB-0f3a36a9b3da937a870cbecbbfa53fe1
# 15    NIST-MATDB-20f44908c68c8c8b88f8e6ccac3ddc11
# 16    NIST-MATDB-0796a426ff4acaca5b2f38ddcda502a4
# 17    NIST-MATDB-cbe62e246612909e69a203d53aad0286
# 18    NIST-MATDB-698d87ea3dc222af53aca3746f3227d3
# 19    NIST-MATDB-aff80a2ff66e5982846a01ae3ce36d1e
# 20    NIST-MATDB-b5cc9ee722145391f636805012aea049
# 21    NIST-MATDB-ee36b2a9095ec91288836a44edfdc823
# 22    NIST-MATDB-694b3058aa659e37dde90bb32da581e4
# 23    NIST-MATDB-366fdecd24bef837eb0cae569bacf316
# 24    NIST-MATDB-5c84285efa1b75d2cf3510e6ab66cfc6
# 25    NIST-MATDB-e0f1ea383b8b290ca83fb4c214ff9cf0
# 26    NIST-MATDB-f194003c556f8f57ac38ece04b86c3b6
# 27    NIST-MATDB-8df803a1cc1143596b41c3b1e86b0e89
# 28    NIST-MATDB-3f5113eb12c69c03ce3ce319d65edc5d
# 29    NIST-MATDB-25536b80165e8b2d1525a255abab835c
# ...                                           ...
# 6001  NIST-MATDB-aa573a31c8c658f678703a20621a7f35
# 6002  NIST-MATDB-5bf72505280aff7e75082eb6d9cc864f
# 6003  NIST-MATDB-46601e4a74a6059d50bb1e513c566999
# 6004  NIST-MATDB-9f6d7a652559ba5497cfdcd8ace33578
# 6005  NIST-MATDB-caa4b8e14ed8e81999fdc3c216b3c927
# 6006  NIST-MATDB-bae9fb9227549d5e43783dd494a63bfb
# 6007  NIST-MATDB-5c42eb2759c29c4f9ac507fe3d9e0b8e
# 6008  NIST-MATDB-fd4118ab9a5243d679099317a1763c3c
# 6009  NIST-MATDB-901f5824839e50316a0fab04e514019d
# 6010  NIST-MATDB-795bce667fe8b1c7ca3e1fe7a4aa249b
# 6011  NIST-MATDB-3e0c919108f2099aaaaa861b52fe55d7
# 6012  NIST-MATDB-6bd85f6a046067ede48b5d5805fbbfea
# 6013  NIST-MATDB-583d697c0afbca86fe273ecf518cf711
# 6014  NIST-MATDB-503ae9b0861c6ff30060a346b362de99
# 6015  NIST-MATDB-69419d0a7094245457084eeded061d35
# 6016  NIST-MATDB-ebb3008a7094797afd3f49ea00b3d051
# 6017  NIST-MATDB-a51fd4c244f3f7dfc1d39ea0f244fc82
# 6018  NIST-MATDB-7685b247ca72329187e1b8fe6723bbf4
# 6019  NIST-MATDB-75522d25e38f40cda94a81c7cf09d755
# 6020  NIST-MATDB-5221a8469d6589c0a439bc47fbac5494
# 6021  NIST-MATDB-f9c6837d761e6484fae50e9f6c126c99
# 6022  NIST-MATDB-b79f378760f114ca0c4788cf5c9c00f2
# 6023  NIST-MATDB-ba9c4127bbebd4af0e48e0429044657a
# 6024  NIST-MATDB-7fc3d1003d03fdeb8a819098fb21a675
# 6025  NIST-MATDB-6fb238246366535807268f8df02ede00
# 6026  NIST-MATDB-611691b0f1619044524da6a6df5a69c5
# 6027  NIST-MATDB-5ac4b4c4a8c7d9aac288b2fe0c8698bb
# 6028  NIST-MATDB-deb4dc3458c9397eb8e205aec27a2969
# 6029  NIST-MATDB-239be5c4611d8c92367f423368110c61
# 6030  NIST-MATDB-7af0cd0c0ca33e0be282b0ddcca7e893
#
#                                                 synonym
# 0                             ((C4H11)2NH2)2Co3(hfbba)4
# 1                                 ((Me2NH2)In(NH2BDC)2)
# 2                                              (Be-BTB)
# 3                                         (C2H5)2dtoaCu
# 4                                    (C4B2H4(COOH)2Li2)
# 5               (C5H14N2)[(VO)3(AsO4)(HAsO4)2(OH)]*3H2O
# 6                                (C6H11NH3)2Mn3(hfbba)4
# 7                                             (Cd(im)2)
# 8                                         (CH3)2-MIL-53
# 9                                     (CH3)2-MIL-53(Al)
# 10                                             (CH3)2CO
# 11                                   (Cr)-MIL-101-SO3Ag
# 12                                             (Cu(db))
# 13                                    (Cu-BTC-DTG-0.92)
# 14                                    (Cu-BTC-DTG-1.52)
# 15                                     (Cu-BTCDTG-0.18)
# 16                         (Cu6(H2O)6(tatb)4*DMA*12H2O)
# 17                                 (CuC8H10O6P2)*(H2O)x
# 18                           (Et2NH2)3[(Cu4Cl)3(TTCA)8]
# 19                                    (H2dab)[Zn2(ox)3]
# 20                                 (H2tdpip)Co3(hfbba)4
# 21    (H3O)4[Ni6(pi3-O)2(pi2-OSC2H6)2(SO4)2(TATB)8/3...
# 22                                 (Hbzza)2]*H2O*C2H5OH
# 23                                          (HF)2-CO2-Y
# 24                                      (HOC2H4)2dtoaCu
# 25                        (In3O)(OH)(ADC)2(IN)2*4.67H2O
# 26                     (In3O)(OH)(ADC)2(NH2IN)2*2.67H2O
# 27                        (LiCl)[Ni(bdc)(ted)0.5] t=100
# 28                         (LiCl)[Ni(bdc)(ted)0.5] t=15
# 29                              (LiCl)[Zn(bdc)(ted)0.5]
# ...                                                 ...
# 6001                    {[Zn(INAIP)(DMF)]*0.5DMF*4H2O}n
# 6002                      {[Zn(l-pzdc)(NH3)2(H2O)]*H2O}
# 6003                {[Zn(m4-TCNQ-TCNQ)bpy]*1.5benzene}n
# 6004             {[Zn(NO2-ip)(dpndi)]*(DMF)1.5(MeOH)1.5
# 6005             {[Zn(NO2-ip)-(bpy)]*(DMF)0.5(MeOH)0.5}
# 6006                         {[Zn(oxo-pba)2(bpy)]4H2O}n
# 6007                            {[Zn(ppmdc)(H2O)2]*H2O}
# 6008              {[Zn-(C10H2O8)0.5(C10S2N2H8)]*5H2O]}n
# 6009                    {[Zn2(bpdc)2(azpy)]*2H2O*2DMF}n
# 6010          {[Zn2(bpdc)2(azpy)]*2H2O*2DMF}n Nanoscale
# 6011                            {[Zn2(btdc)2(bpy)]*xS}n
# 6012                           {[Zn2(btdc)2-(bpy)]*yS}n
# 6013                   {[Zn2(H2dht)(dht)0.5)(azpy)0.5]}
# 6014                           {[Zn2(L)(OH)]*2DMF*H2O}n
# 6015                      {[Zn2(MTB)(H2O)2]*3H2O*3DMF}n
# 6016                     {[Zn2(OH)(AZPY)(BDC)1.5]*H2O}n
# 6017                 {[Zn2BIB1.5SPA(OH)(H2O)]*1.75H2O}n
# 6018                    {[Zn3(bpdc)3(azpy)]*4H2O*2DEF}n
# 6019                     {[Zn3(DLlac)2(pybz)2]*2.5DMF}n
# 6020                      {[Zn3(L)3(DPB)1.5]-6DMF-H20}n
# 6021                       {[Zn3(ntb)2-(EtOH)2]*4EtOH}n
# 6022                          {[Zn3(ptp)3](DMF)2-(H2O)}
# 6023                     {[Zn4(BDC)4(BPDA)4]*5DMF*3H2O}
# 6024    {[Zn4(bpydb)3(datz)2(H2O)](DMF)4(EtOH)5(H2O)8}n
# 6025       {[Zn4O(bfbpdc)3-(bpy)0.5(H2O)]*(3DMF)(H2O)}n
# 6026                             {[Zn4O(L)3(DMF)2] xG}n
# 6027                             {[ZnL(HCO2)(H2O)]*DMF}
# 6028                              {[ZnL(HCO2)]*DMF*H2O}
# 6029                {[{Dy4(mu2-OH)}3(hett)8]*9NO3*6H2O}
# 6030                {[{Nd4(mu2-OH)}3(hett)8]*9NO3*6H2O}
#
# [6031 rows x 2 columns]
